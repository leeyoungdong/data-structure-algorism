# %% [markdown]
# # **너비와 깊이 우선 탐색(BFS,DFS)**

# %% [markdown]
# # **BFS(Breadth-First Search, 너비우선탐색)**

# %% [markdown]
# BFS는 그래프 전체를 탐색 하는 방법중 하나, 현재 확인하는 노드의 인접한 노드들을 먼저 탐색 하는것.
#
# 시작 정점으로부터 가까운 정점을 먼저 방문하고, 멀리 떨어져 있는 정점을 나중에 방문하는 순회방식으로 노드를 탐색한다.
#
# 구현은 Queue에 이웃하는 정점을 다 담아놓고 차례대로 pop하는 방식으로 구현.
#
# 주로 두 노드 사이의 최단 경로 혹은 임의의 경로를 찾고 싶을때 이용

# %% [markdown]
# **장점**
#
# * 노드의 수가 적고 깊이가 얕은 경우 빠르게 동작
# * 단순 검색 속도가 DFS보다 빠르다
# * 너비를 우선 탐색하기에 답이 되는 경로가 여러개인 경우에도 최단 경로임을 보장
# * 최단경로가 존재한다면 어느 한 경로가 무한히 깊다고해도 최단경로를 반드시 찾을 수 있음

# %% [markdown]
# **단점**
# * 재귀 호출의 DFS와 달리 큐에 다음 탐색할 정점들을 저장해야하므로 저장공간이 많이 필요
# * 노드의 수가 늘어나면 탐색해야 하는 노드가 많아져 비현실적임

# %% [markdown]
# # **DFS(Depth-First Search, 깊이우선탐색)**

# %% [markdown]
# DFS는 그래프 전체를 탐색 하는 방법중 하나, 시작점 부터 다음분기(Branch)로 넘어가기전에 해당 분기를 완벽하게 탐색하고 넘어가는 방법이다.
#
# 먼저 보이는 노드부터 계속해서 깊이를 늘려가며 탐색하고, 더 이상 탐색할 노드가 없다면 이전 노드로 돌아가서 다른 브랜치를 깊이 파보는 형식.
#
# Stack이나 재귀함수를 통해서 구현할 수 있다.

# %% [markdown]
# **장점**
#
# * 현재 경로상의 노드들면 기억하면 되므로, 저장공간의 수요가 비교적 적다
# * 목표 노드가 깊은 단계에 있는 경우에도 해를 빨리 구할 수 있다.
# * 구현이 BFS보다 간단하다

# %% [markdown]
# **단점**
#
# * 단순 검색속도가 BFS보다 느리다.
# * 깊이 우선 탐색은 해를 구하면 탐색이 종료, 구한 해가 최단 경로가 된다는 보장이없음. 목표에 이르는 경로가 다수인 경우, DFS를 통해 구한 해가 최적이 아닐 수 있다. DFS를 사용하여 최단 경로를 구하기 위해서는, 모든 경로를 전부 확인해 보아야 한다.

# %% [markdown]
# # **BFS와 DFS의 탐색 순서**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **주의**
#
# 노드를 큐 혹은 스택에 넣을때, 방문 여부를 반드시 표시해주어야 함.
# 그렇지 않으면, 자료구조에 노드가 중복되게 들어갈 수 있음. 최악의 경우 무한루프에 빠질 수 있음
