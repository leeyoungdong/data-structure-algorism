# %% [markdown]
# # **Tree**

# %% [markdown]
# 트리는 그래프의 일종으로, 부모 노드 밑에 여러 자식노드가 연결, 자식노드 각각에 다시 자식 노드가 연결되는 재귀적 형태의 자료구조.
#
# 노드들은 서로 다른 자식 노드를 가지며 이때 각 노드는 재사용 되지 않는다. 트리는 다음과 같은 특징을 갖음음

# %% [markdown]
# * 반도시 하나의 루트 노드만이 존재
# * 모든자식노드는 한 개의 부모노드만을 가짐
# * 서로 다른 임의의 두 노드에 대해 두 노드를 연결하는 경로는 유일
# * 사이클을 가지는 노드 집합이 존재 하지않음
# * 노드가 N개인 트리는 항상 N-1개의 간선을 갖음음

# %% [markdown]
# # **트리 용어**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 노드(node): 트리를 구성하는 기본원소
# * 루트 노드(root node / root): 트리에서 부모가 없는 최상위 노드, 트리의 시작점
# * 부모 노드(parent node): 루트노드 방향으로 직접 연결된 노드
# * 자식 노드(child node): 루트노드 반대방향으로 직접 연결된 노드
# * 형제 노드(siblings node): 같은 부모 노드를 갖는 노드들
# * 잎 노드(leaf node) / 단말 노드(terminal node): 자식이 없는 노드
# * 경로(path):  한 노드에서 다른 한노드에 이르는 길 사이에 있는 노드들의 순서
# * 길이(length): 출발 노드에서 도착 노드까지 거치는 노드의 개수
# * 깊이(depth): 루트 경로의 길이
# * 레벨(level): 루트 노드(level=1)부터 노드까지 연결된 링크 수의 합
# * 높이(height): 가장 긴 루트 경로의 길이
# * 차수(degree): 각 노드의 자식의 개수
# * 트리의 차수(degree of tree): 트리의 최대 차수 = max[deg1,... degn]
# * 크기(size): 노드의 개수
# * 너비(witdth): 가장 많은 노드를 갖고 있는 레벨의 크기기

# %% [markdown]
# # **Binary tree**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이진 트리(binary tree)는 각각의 노드가 최대 두개의 자식 노드를 가지는 트리를 말한다. 즉, 모든 노드의 차수(degree)가 2이하인 트리를 말한다. 이진 트리의 모든 서브 트리들은 모두 이진트리이다.

# %% [markdown]
# # **순회(Traversal)방법**

# %% [markdown]
# * 전위 순회(preorder)
#  1. 노드를 방문
#  2. 왼쪽 서브 트리를 전위 순회
#  3. 오른쪽 서브 트리를 전위 순회
# * 중위 순회(inorder)
#  1. 왼쪽 서브 트리를 중위 순회
#  2. 노드를 방문
#  3. 오른쪽 서브 트리를 중위 순회
# * 후위 순회(postorder)
#  1. 왼쪽 서브 트리를 후위 순회
#  2. 오른쪽 서브 트리를 후위 순회
#  3. 노드를 방문
# * 레벨 순서 순회(level-order)
#  * 모든 노드를 낮은 레벨부터 차례대로 순회한다. 레벨 순서 순회는 너비 우선 순회(breadth-first traversal)라고도 한다.

# %% [markdown]
# # **full binary tree**

# %% [markdown]
# > 들여쓴 블록
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# full binary tree는 단말 노드들을 제외한 모든 노드들이 2개의 자식 노드를 가지는 binary tree이다

# %% [markdown]
# # **complete binary tree**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 완전 이진 트리(complete binary tree)는 마지막 level을 제외한 나머지 level에 노드들이 가득 차있고, 마지막 level에서 노드는 가장 왼쪽부터 채워지는 형태의 binary tree

# %% [markdown]
# # **bst(binary search tree)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이진 탐색 트리(binary search tree)는 아래의 성질을 갖고 있는 이진 트리이다.

# %% [markdown]
# * 각각의 모든 노드들의 값(key)은 중복된 값이 아니다.
# * 노드의 왼쪽 서브트리에는 그 노드의 값보다 작은 값들을 지닌 노드들로 이뤄져 있다.
# * 노드의 오른쪽 서브트리에는 그 노드의 값보다 큰 값들을 지닌 노드들로 이뤄져 있다.
# * 좌우 서브트리는 각각 다시 이진 탐색트리여야 한다.

# %% [markdown]
# **탐색(Search)**

# %% [markdown]
# 검색하고자 하는 값을 루트 노드와 먼저 비교, 일치할 경우 루트 노드를 리턴
# * 불일치하고 검색하고자자자 하는 값이 루트 노드의 값보다 작을 경우 왼쪽 서브트리에서 재귀적으로 검색
# * 불일치하고 검색하고자 하는 값이 루트 노드의 값보다 큰 경우 오른쪽 서브트리에서 재귀적으로 검색색

# %% [markdown]
# **삽입(Insert)**
#
# 삽입을 하기 전, 탐색을 수행. 트리를 탐색한 후 키와 일치하는 노드가 없으면 마지막 노드에서 키와 노드의 크기를 비교해 왼쪽 or 오른쪽에 새로운 노드를 삽입입

# %% [markdown]
# **삭제(Delete)**

# %% [markdown]
# 삭제하려는 노드의 자식 수에 따라
# * 자식 노드가 없는 노드(리프 노드)삭제: 해당 노드를 삭제
# * 자식 노드가 1개인 노드 삭제: 해당 노드를 삭제하고 그 위치에 해당 노드의 자식 노드를 대입
# * 자식 노드가 2개인 노드 삭제: 삭제하고자 하는 노드의 값을 해당 노드의 왼쪽 서브트리에서 가장 큰 값으로 변경 or 오른쪽 서브트리엣 가장 작은 값으로 변경한 뒤, 해당 노드(왼쪽 서브트리에서 가장 큰 값을 가지는 노드 or 오른쪽 서브트리에서 가장 작은 값을 가지는 노드)를 삭제

# %% [markdown]
# **시간복잡도**

# %% [markdown]
# BST의 탐색, 삽입, 삭제의 복잡도 = O(h)(h=bst의 높이)
#
# bst는 평균 시간 복잡도가 O(log_2 n)이지만 최악의 경우 O(n)이다. (skewed tree면 node의 수만큼 시간이 소요)
#
# 트리가 complete binary tree 거나 full binary tree 이면 O(log_2 n), skewed tree 이면 O(n)의 시간복잡도를 갖음음
