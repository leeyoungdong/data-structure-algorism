# %% [markdown]
# # **Linked list**

# %% [markdown]
# linked list는 서로 떨어져 있는 데이터를 메모리 주소를 참조함으로써 이어진 것처럼 사용할 수 있다. linked list는 구조체가 이어진 형태로 존재, 이 구조체를 노드라고 부름.
#
#  노드는 값을 담고있는 데이터 필드와 다음 구조체를 가리키는 링크 필드(포인터)로 구성됨. 포인터가 다음 구조체의 주소를 담고 있음.
#
#   linked list의 맨 첫 원소를 가리키는 head포인터와 맨 마지막 원소를 가리키는 tail포인터를 통해, 리스트의 요소에 접근하거나, 수정한다. linked list는 구현 방법에따라
#
# [single linked list, double linked list, circular linked list] 등으로 구분할 수 있다.

# %% [markdown]
# **Array vs Linked list**

# %% [markdown]
# array에서 중간에 값을 삽입하고 싶다면, 삽입할 위치 뒤의 모든 데이터가 한칸 씩 이동해야 한다는 단점이 있다. array가 할당 받은 공간이 부족한데, 메모리상 뒤쪽의 메모리가 비어있지 않으면, 모든 데이터가 더 큰 홀로 이사를 가야한다는 단점도 존재
#
# linked list는 연속된 공간을 사용하지 않아도 되기 때문에 앞서 언급했던 array의 단점을 모두 해소할 수 있다. 그러나 N번째 데이터를 참조하고 싶을 때, 계속해서 다음 주소를 참조하는 식으로 따라가야 하므로 메모리 참조에 시간이 오래 걸린다.
#
# 따라서 삽입 과 삭제가 빈번한 경우 - linked list / 참조가 빈번한 경우 - array를 사용하는것이 바람직

# %% [markdown]
# **Time Complexity 비교**

# %% [markdown]
# 구분 Array Linked list
#
# ---
#
# insert O(n)  O(1)
#
# ---
#
# delete O(n)  O(1)
#
# ---
#
# find O(1)  O(n)

# %% [markdown]
# **삽입, 삭제, 접근 방법**

# %% [markdown]
# * 접근: 원하는 원소가 나올때까지 링크필드(포인터, 다음노드)를 계속해서 탐색한다.
# * 삽입: 삽입할 노드의 next에 현재 위치의 next를 연결한 후, 현재위치의 next에 삽입할 노드의 주소를 넣어준다.
# * 삭제: 삭제할 노드의 next를 앞선 노드의 next에 연결해준다.

# %% [markdown]
# **기본적인 linked list 구조(single linked list 구조)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **single linked list**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Linked list 에서 언급한 내용은 모두 single linked list에 해당. single linked list는  링크드 리스트 중에서도 가장 기본적인 구조로 이뤄짐.
#
#  head에서 tail까지 단방향으로 포인터가 이어져 있으므로 N번째 노드에서 N-1번째 노드에 접근할 수 없다. 대신, 다시 head로부터 N-1번의 탐색을 통해 접근해야함

# %% [markdown]
# # **double linked list**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# single linked list는 단방향 연결이기 때문에 한번 다음 노드로 이동하면, 이전 노드로 돌오가기 힘들다는 단점이 존재
#
# double linked list는 뒤의 노드의 주소뿐 아니라, 이전 노드의 주소도 담고 있다. 하나의 노드는 하나의 데이터와 두개의 링크를 갖고 있으며, 각 링크를 prev와 next라고 부름. 다음 노드를 참조하고 싶으면 next링크가 담고 있는 주소를 확인하면 되고, 이전의 노드를 참조하고 싶다면 prev 링크가 가지는 주소를 확인하면 됨

# %% [markdown]
# # **circular linked list**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# tail이 다시 head를 가리키는 주고를 갖고 있음. 따라서, tail 노드의 next에는  NULL이 들어가는 대신, head의 주소가 들어감
